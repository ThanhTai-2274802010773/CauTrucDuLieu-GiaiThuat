# %% [markdown]
# ## Chuong 3

# %% [markdown]
# ##### Thuc hanh 01:

# %%
import math
import sys
class Graph():
    def __init__(cung, dinh):
        cung.x = dinh
        cung.graph = [[0 for column in range(dinh)]
        for row in range(dinh)]
    def inketqua(cung, L, a):
        print ("đỉnh nguồn xuất phát từ: ")
        for nut in range(cung.x):
            print (a," đến đỉnh ",nut, "độ dài đường đi là: ", L[nut])
    def duongdinhonhat(cung, L, P):
        min = sys.maxsize
        for x in range(cung.x):
            if L[x] < min and P[x] == False:
                min = L[x]
                min_index = x
                return min_index
    def timduongdi(cung, a):
        L = [sys.maxsize] * cung.x
        L[a] = 0
        P = [False] * cung.x
        for cout in range(cung.x):
            u = cung.duongdinhonhat(L, P)
            P[u] = True
            for x in range(cung.x):
                if cung.graph[u][x] > 0 and P[x] == False and L[x] > L[u] + cung.graph[u][x]:
                    L[x] = L[u] + cung.graph[u][x]
                    cung.inketqua(L, a)

g = Graph(6) #đồ thị vô hướng
g.graph = [[0, 3, 0, 1, 0, 0],
[3, 0, 5, 2, 0, 0],
[0, 5, 0, 0, 4, 2],
[1, 2, 0, 0, 6, 0],
[0, 0, 4, 6, 0, 7],
[0, 0, 2, 0, 7, 0]];

g.timduongdi(0);
# Out:
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  1
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  8
# 0  đến đỉnh  3 độ dài đường đi là:  1
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  8
# 0  đến đỉnh  3 độ dài đường đi là:  1
# 0  đến đỉnh  4 độ dài đường đi là:  12
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  8
# 0  đến đỉnh  3 độ dài đường đi là:  1
# 0  đến đỉnh  4 độ dài đường đi là:  12
# 0  đến đỉnh  5 độ dài đường đi là:  10
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  8
# 0  đến đỉnh  3 độ dài đường đi là:  1
# 0  đến đỉnh  4 độ dài đường đi là:  7
# 0  đến đỉnh  5 độ dài đường đi là:  10

# %%
import math
import sys
class Graph():
    def __init__(cung, dinh):
        cung.x = dinh
        cung.graph = [[0 for column in range(dinh)]
        for row in range(dinh)]
    def inketqua(cung, L, a):
        print ("đỉnh nguồn xuất phát từ: ")
        for nut in range(cung.x):
            print (a," đến đỉnh ",nut, "độ dài đường đi là: ", L[nut])
    def duongdinhonhat(cung, L, P):
        min = sys.maxsize
        for x in range(cung.x):
            if L[x] < min and P[x] == False:
                min = L[x]
                min_index = x
        return min_index
    def timduongdi(cung, a):
        L = [sys.maxsize] * cung.x
        L[a] = 0
        P = [False] * cung.x
        for cout in range(cung.x):
            u = cung.duongdinhonhat(L, P)
            P[u] = True
            for x in range(cung.x):
                if cung.graph[u][x] > 0 and P[x] == False and L[x] > L[u] + cung.graph[u][x]:
                    L[x] = L[u] + cung.graph[u][x]
                    cung.inketqua(L, a)
g = Graph(6)
g.graph =[[0, 5, 0, 10, 0, 0],
[5, 0, 15, 2, 0, 0],
[0, 15, 0, 0, 1, 12],
[10, 2, 0, 0, 6, 0],
[0, 0, 1, 6, 0, 7],
[0, 0, 12, 0, 7, 0]];
g.timduongdi(0);
# Out:
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  10
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  20
# 0  đến đỉnh  3 độ dài đường đi là:  10
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  20
# 0  đến đỉnh  3 độ dài đường đi là:  7
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  20
# 0  đến đỉnh  3 độ dài đường đi là:  7
# 0  đến đỉnh  4 độ dài đường đi là:  13
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  14
# 0  đến đỉnh  3 độ dài đường đi là:  7
# 0  đến đỉnh  4 độ dài đường đi là:  13
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  5
# 0  đến đỉnh  2 độ dài đường đi là:  14
# 0  đến đỉnh  3 độ dài đường đi là:  7
# 0  đến đỉnh  4 độ dài đường đi là:  13
# 0  đến đỉnh  5 độ dài đường đi là:  20

# %%
import math
import sys
class Graph():
    def __init__(cung, dinh):
        cung.x = dinh
        cung.graph = [[0 for column in range(dinh)]
                      for row in range(dinh)]
    def inketqua(cung, L, a):   
        print ("đỉnh nguồn xuất phát từ: ") 
        for nut in range(cung.x):
            print (a," đến đỉnh ",nut, "độ dài đường đi là: ", L[nut])
    def duongdinhonhat(cung, L, P):
        min = sys.maxsize   
        for x in range(cung.x):
            if L[x] < min and P[x] == False:
                min = L[x]
                min_index = x
        return min_index
    def timduongdi(cung, a):
        L = [sys.maxsize] * cung.x
        L[a] = 0
        P = [False] * cung.x
        for cout in range(cung.x):
            u = cung.duongdinhonhat(L, P)
            P[u] = True
            for x in range(cung.x):
                if cung.graph[u][x] > 0 and P[x] == False and L[x] > L[u] + cung.graph[u][x]:
                    L[x] = L[u] + cung.graph[u][x]
                    cung.inketqua(L, a)
g = Graph(6)
g.graph = [[0, 7, 0, 14, 0, 0],
 [0, 0, 4, 1, 0, 0],
 [0, 0, 0, 0, 2, 1],
 [0, 0, 1, 0, 5, 0],
 [0, 0, 0, 0, 0, 5],
 [0, 0, 0, 0, 0, 0]];
g.timduongdi(0);
# Out:
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  14
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  11
# 0  đến đỉnh  3 độ dài đường đi là:  14
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  11
# 0  đến đỉnh  3 độ dài đường đi là:  8
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9
# 0  đến đỉnh  3 độ dài đường đi là:  8
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9
# 0  đến đỉnh  3 độ dài đường đi là:  8
# 0  đến đỉnh  4 độ dài đường đi là:  13
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9
# 0  đến đỉnh  3 độ dài đường đi là:  8
# 0  đến đỉnh  4 độ dài đường đi là:  11
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  7
# 0  đến đỉnh  2 độ dài đường đi là:  9
# 0  đến đỉnh  3 độ dài đường đi là:  8
# 0  đến đỉnh  4 độ dài đường đi là:  11
# 0  đến đỉnh  5 độ dài đường đi là:  10

# %% [markdown]
# ##### Thuc hanh 02:

# %%
g = Graph(6) #đồ thị có hướng
g.graph = [[0, 3, 0, 4, 0, 0],
[0, 0, 6, 2, 0, 0],
[0, 0, 0, 0, 4, 3],
[0, 0, 1, 0, 4, 0],
[0, 0, 0, 0, 0, 5],
[0, 0, 0, 0, 0, 0]];
g.timduongdi(0);
# Out:
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  3 độ dài đường đi là:  4
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  9
# 0  đến đỉnh  3 độ dài đường đi là:  4
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  5
# 0  đến đỉnh  3 độ dài đường đi là:  4
# 0  đến đỉnh  4 độ dài đường đi là:  9223372036854775807
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  5
# 0  đến đỉnh  3 độ dài đường đi là:  4
# 0  đến đỉnh  4 độ dài đường đi là:  8
# 0  đến đỉnh  5 độ dài đường đi là:  9223372036854775807
# đỉnh nguồn xuất phát từ:
# 0  đến đỉnh  0 độ dài đường đi là:  0
# 0  đến đỉnh  1 độ dài đường đi là:  3
# 0  đến đỉnh  2 độ dài đường đi là:  5
# 0  đến đỉnh  3 độ dài đường đi là:  4
# 0  đến đỉnh  4 độ dài đường đi là:  8
# 0  đến đỉnh  5 độ dài đường đi là:  8
